# %% [markdown]
#  ## Exercício 20
# ### Análise de Consumo de Energia e Emissões de CO2
# ### Análises e Visualizações:
# ### • Crie um Boxplot que compare o consumo de energiasrenováveis e fósseis por continente.
# ### • Use gráficos de linha para mostrar a evolução do consumo de energias renováveis e fósseis e as emissões de CO2 ao longo do tempo.
# ### • Visualize a contribuição dos setores (indústria, transporte, etc.) para as emissões de CO2 por continente.
# ### • Crie gráficos de dispersão para analisar a correlação entre o consumo de energia fóssil e as emissões de CO2 por continente, incluindouma linha de regressão.
# ### • Crie gráficos interativos que permitam visualizar como o consumo energético impacta as emissões ao longo do tempo em diferentes regiões. Explique como o consumo de energia está relacionado às emissões de CO2, destacando diferenças regionais e setoriais.

# %%
import pandas as pd
import plotly.express as px
df = pd.read_csv("dados_energia_simulados_ptbr.csv")
df.head(5)
# Out:
#     Ano      Continente    País        Setor  Consumo_Energia_Renovável (MWh)  \
# 0  2016         Oceania   China    Comercial                      7397.685031
# 1  2020  América do Sul  Brasil   Transporte                       971.598203
# 2  2003  América do Sul   China    Indústria                      5455.079849
# 3  2019  América do Sul   China    Indústria                      2778.436239
# 4  2019  América do Sul  Rússia  Residencial                      6429.091172
#
#    Consumo_Energia_Fóssil (MWh)  Emissões_CO2 (toneladas)  \
# 0                  12535.546950              78910.224574
# 1                  10036.494790              93896.756176
# 2                   6789.106081              22068.881619
# 3                  12941.548015              49534.631946
# 4                  11755.142517             117101.029860
#
#    PIB (milhões de USD)  População (milhões)
# 0          2.463037e+06           165.908531
# 1          6.152132e+06            19.864661
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 9 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   Ano                              2000 non-null   int64
#  1   Continente                       2000 non-null   object
#  2   País                             2000 non-null   object
#  3   Setor                            2000 non-null   object
#  4   Consumo_Energia_Renovável (MWh)  2000 non-null   float64
#  5   Consumo_Energia_Fóssil (MWh)     2000 non-null   float64
#  6   Emissões_CO2 (toneladas)         2000 non-null   float64
#  7   PIB (milhões de USD)             2000 non-null   float64
#  8   População (milhões)              2000 non-null   float64
# dtypes: float64(5), int64(1), object(3)
# memory usage: 140.8+ KB

# %%
df.describe()
# Out:
#                Ano  Consumo_Energia_Renovável (MWh)  \
# count  2000.000000                      2000.000000
# mean   2010.991000                      5047.241453
# std       6.750534                      1989.358867
# min    2000.000000                     -1376.610759
# 25%    2005.000000                      3628.462963
# 50%    2011.000000                      5048.885126
# 75%    2017.000000                      6486.014516
# max    2022.000000                     11590.030991
#
#        Consumo_Energia_Fóssil (MWh)  Emissões_CO2 (toneladas)  \
# count                   2000.000000               2000.000000
# mean                    9972.486177              99890.594067
# std                     5115.427170              50561.848340
# min                    -7908.823002             -67666.540624
# 25%                     6534.967027              64374.810818
# 50%                     9871.284228             100749.256341
# ...

# %%
df.isnull().sum()
# Out:
# Ano                                0
# Continente                         0
# País                               0
# Setor                              0
# Consumo_Energia_Renovável (MWh)    0
# Consumo_Energia_Fóssil (MWh)       0
# Emissões_CO2 (toneladas)           0
# PIB (milhões de USD)               0
# População (milhões)                0
# dtype: int64

# %%
df_agrupado=df.groupby("Continente")[["Consumo_Energia_Renovável (MWh)","Consumo_Energia_Fóssil (MWh)"]].sum()

# %%
df_agrupado
# Out:
#                   Consumo_Energia_Renovável (MWh)  \
# Continente
# América do Norte                     1.728312e+06
# América do Sul                       1.715953e+06
# Europa                               1.673929e+06
# Oceania                              1.725809e+06
# África                               1.650154e+06
# Ásia                                 1.600325e+06
#
#                   Consumo_Energia_Fóssil (MWh)
# Continente
# América do Norte                  3.316335e+06
# América do Sul                    3.524776e+06
# Europa                            3.400128e+06
# Oceania                           3.515681e+06
# África                            3.076956e+06
# Ásia                              3.111096e+06

# %%
df.columns
# Out:
# Index(['Ano', 'Continente', 'País', 'Setor', 'Consumo_Energia_Renovável (MWh)',
#        'Consumo_Energia_Fóssil (MWh)', 'Emissões_CO2 (toneladas)',
#        'PIB (milhões de USD)', 'População (milhões)'],
#       dtype='object')

# %%
oceania_df = df[df["Continente"]=="Oceania"]
americaDoSul_df = df[df["Continente"]=="América do Sul"]
europa_df = df[df["Continente"]=="Europa"]
americaDoNorte = df[df["Continente"]=="América do Norte"]
africa_df = df[df["Continente"]=="África"]
asia_df = df[df["Continente"]=="Ásia"]

# %%
oceania_df
# Out:
#        Ano Continente            País        Setor  \
# 0     2016    Oceania           China    Comercial
# 8     2009    Oceania  Estados Unidos  Residencial
# 10    2011    Oceania       Austrália    Comercial
# 11    2003    Oceania          Brasil  Residencial
# 12    2008    Oceania          Brasil   Transporte
# ...    ...        ...             ...          ...
# 1960  2004    Oceania           China   Transporte
# 1970  2014    Oceania  Estados Unidos   Transporte
# 1975  2015    Oceania           China    Indústria
# 1978  2007    Oceania       Austrália    Comercial
# 1998  2009    Oceania  Estados Unidos  Residencial
#
#       Consumo_Energia_Renovável (MWh)  Consumo_Energia_Fóssil (MWh)  \
# 0                         7397.685031                  12535.546950
# 8                         6005.195632                   7332.285514
# 10                        5548.700023                  10029.134396
# 11                        6649.217009                   9992.382375
# ...
