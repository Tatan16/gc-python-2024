# %% [markdown]
# ## Exercício 21
# ## Análise dos dados da COVID-19
# ### Perguntas
# ### • Quais são os 5 estados brasileiros com mais casos e mortes acumuladas?
#
# ## Exploração de diferentes tipos de gráficos:
# ### • Justifique a utilização de cada gráfico.
# ### • Pelo menos duas perguntas devem testar diferentes tipos de gráficos para a mesma análise (por exemplo, comparar gráficos de linha com gráficos de barras). Explicar como a escolha do tipo de gráfico influencia a interpretação dos dados e se há algum tipo de visualização que seja mais adequado para responder à pergunta proposta

# %%
import pandas as pd
import plotly.express as px
df_casos = pd.read_csv("biweekly_cases.csv")
display(df_casos)
# Out:
#             date      World  Afghanistan  Africa  Albania  Algeria  Andorra  \
# 0     2020-01-22        NaN          NaN     NaN      NaN      NaN      NaN
# 1     2020-01-23        NaN          NaN     NaN      NaN      NaN      NaN
# 2     2020-01-24        NaN          NaN     NaN      NaN      NaN      NaN
# 3     2020-01-25        NaN          NaN     NaN      NaN      NaN      NaN
# 4     2020-01-26        NaN          NaN     NaN      NaN      NaN      NaN
# ...          ...        ...          ...     ...      ...      ...      ...
# 1138  2023-03-05  1974121.0        283.0  8890.0    113.0     52.0      9.0
# 1139  2023-03-06  1949957.0        253.0  8009.0    112.0     51.0      9.0
# 1140  2023-03-07  1900262.0        255.0  8303.0     91.0     62.0      9.0
# 1141  2023-03-08  1833409.0        270.0  9002.0    107.0     63.0     24.0
# 1142  2023-03-09  1789642.0        236.0  9431.0    112.0     64.0     24.0
#
# ...

# %%
df_casos.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1143 entries, 0 to 1142
# Columns: 232 entries, date to Zimbabwe
# dtypes: float64(231), object(1)
# memory usage: 2.0+ MB

# %%
df_casos.describe()
# Out:
#               World   Afghanistan         Africa      Albania       Algeria  \
# count  1.131000e+03   1095.000000    1109.000000   1084.00000   1097.000000
# mean   8.343122e+06   2676.410046  157885.160505   4318.51476   3464.363719
# std    7.862067e+06   4300.273653  155593.017277   5334.63550   4490.770994
# min    1.696900e+04      3.000000       2.000000     42.00000     19.000000
# 25%    4.086790e+06    541.000000   32208.000000    294.00000    149.000000
# 50%    6.939271e+06   1066.000000  111801.000000   1837.00000   2098.000000
# 75%    8.956796e+06   2868.000000  201211.000000   7294.00000   4567.000000
# max    4.662814e+07  25371.000000  618823.000000  31507.00000  25967.000000
#
#            Andorra        Angola     Anguilla  Antigua and Barbuda  \
# count  1091.000000   1073.000000  1065.000000          1078.000000
# mean    614.319890   1373.338304    51.291080           118.226345
# std    1018.234658   2450.146597    83.578009           231.380594
# ...

# %% [markdown]
# ### • Como foi a evolução mundial da COVID-19?

# %%
fig_1 = px.line(df_casos, x="date", y="World",
               labels={
                   "date":"Data",
                   "World":"Casos em Milhões"
               })

fig_1.show()

# %% [markdown]
# ### • Quais são os 5 países com mais casos e mortes acumulados?

# %%
df_mortes = pd.read_csv("total_deaths.csv")
df_mortes = pd.melt(df_mortes, id_vars="date", var_name="Paises", value_name="Mortes")
remocao = ["World", "High income", "Upper middle income", "Lower middle income",
           "Europe", "North America", "Asia", "South America", "European Union"]
top_5_paises = df_mortes[~df_mortes["Paises"].isin(remocao)].groupby("Paises").max().sort_values(by="Mortes", ascending=False).head(5)
top_5_paises
# Out:
#                      date     Mortes
# Paises
# United States  2023-03-09  1123836.0
# Brazil         2023-03-09   699276.0
# India          2023-03-09   530779.0
# Russia         2023-03-09   388478.0
# Mexico         2023-03-09   333188.0

# %%
fig_2 = px.bar(top_5_paises, x=top_5_paises.index, y="Mortes", title="5 Paises com mais Mortes por COVID-19",
              labels={
                  "Paises":"Paises",
                  "Mortes":"Número de Mortes"
              }, color=top_5_paises.index)

fig_2.show()

# %% [markdown]
# ### • Quais são os 5 países mais avançados em relação à vacinação da população?

# %%
df_vacina = pd.read_csv("vaccinations.csv")
display(df_vacina)
# Out:
#            location iso_code        date  total_vaccinations  \
# 0       Afghanistan      AFG  2021-02-22                 0.0
# 1       Afghanistan      AFG  2021-02-23                 NaN
# 2       Afghanistan      AFG  2021-02-24                 NaN
# 3       Afghanistan      AFG  2021-02-25                 NaN
# 4       Afghanistan      AFG  2021-02-26                 NaN
# ...             ...      ...         ...                 ...
# 196241     Zimbabwe      ZWE  2022-10-05          12219760.0
# 196242     Zimbabwe      ZWE  2022-10-06                 NaN
# 196243     Zimbabwe      ZWE  2022-10-07                 NaN
# 196244     Zimbabwe      ZWE  2022-10-08                 NaN
# 196245     Zimbabwe      ZWE  2022-10-09          12222754.0
#
#         people_vaccinated  people_fully_vaccinated  total_boosters  \
# 0                     0.0                      NaN             NaN
# 1                     NaN                      NaN             NaN
# ...

# %%
remocao_2 = ["World", "Lower middle income", "Upper middle income", "High income", "Low income",
             "Asia", "Africa", "Europe", "North America", "South America", "European Union"]
top_5_evolucao_vacina = df_vacina[~df_vacina["location"].isin(remocao_2)].groupby("location").max().sort_values(by="people_vaccinated", ascending=False).head(5)
top_5_evolucao_vacina
# Out:
#               iso_code        date  total_vaccinations  people_vaccinated  \
# location
# China              CHN  2023-02-09        3.491077e+09       1.310292e+09
# India              IND  2024-08-12        2.206868e+09       1.027439e+09
# United States      USA  2023-05-09        6.767288e+08       2.702272e+08
# Indonesia          IDN  2023-11-23        4.481999e+08       2.044194e+08
# Brazil             BRA  2023-03-22        4.864364e+08       1.896434e+08
#
#                people_fully_vaccinated  total_boosters  \
# location
# China                     1.276760e+09     826913000.0
# India                     9.519906e+08     227438524.0
# United States             2.306373e+08     133062763.0
# Indonesia                 1.749651e+08      69356250.0
# Brazil                    1.761642e+08     126388587.0
#
#                daily_vaccinations_raw  daily_vaccinations  \
# location
# China                      24741000.0          22424286.0
# ...

# %%
fig_3 = px.bar(top_5_evolucao_vacina, x=top_5_evolucao_vacina.index, y="people_vaccinated", color=top_5_evolucao_vacina.index,
                    labels={
                        "location":"Paises",
                        "people_vaccinated":"Total Vacunados"
                    })

fig_3.show()

# %% [markdown]
# ### • Como está a evolução de casos e mortes no Brasil em comparação com o mundo?

# %%
df_brazil_casos = pd.read_csv("cases-brazil-total.csv")
df_brazil_casos = df_brazil_casos.drop(0)
df_brazil_casos_new = df_brazil_casos.groupby("state")[["date", "totalCases", "deaths"]].sum()
display(df_brazil_casos)s
# Out:
#   Cell In[158], line 4
#     display(df_brazil_casos)s
#                             ^
# SyntaxError: invalid syntax

# %%
fig_4 = px.line(df_brazil_casos, x="date", y="totalCases", color=df_brazil_casos.index)

fig_4
