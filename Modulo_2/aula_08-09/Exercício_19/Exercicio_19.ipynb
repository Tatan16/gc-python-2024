# %% [markdown]
# ## Exercício 19
# ### Análise de Pinguins e História dos Oceanos
# ### Tarefas
# ### • Existem valores ausentes ou inconsistentes no dataset? Se sim, como você trataria esses dados para garantir a qualidade da análise?
# ### • Realize uma análise exploratória dos dados para entender as características físicas (como peso, comprimento do bico e comprimento da asa) das três espécies de pinguins. Utilize agregações e agrupamentos para comparar essas características entre as espécies.
# ### • Crie gráficos para visualizar as diferenças entre as espécies de pinguins com base nas características físicas. Use gráficos de dispersão, boxplot e histogramas para mostrar as distribuições e comparações entre as variáveis.
# ### • Com base nas suas visualizações, escreva uma breve narrativa que conecte os dados com a situação atual dos pinguins. O que os dados sugerem sobre o habitat e as condições físicas desses animais? Como isso pode ser interpretado em relação às mudanças ambientais?

# %%
import matplotlib.pyplot as plt
import plotly.express as px
import pandas as pd
import seaborn as sn
penguinsExtended_df = pd.read_csv("penguinsExtended.csv")
penguinsExtended_df
# Out:
#      species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0     Adelie  Biscoe            53.4           17.8              219.0
# 1     Adelie  Biscoe            49.3           18.1              245.0
# 2     Adelie  Biscoe            55.7           16.6              226.0
# 3     Adelie  Biscoe            38.0           15.6              221.0
# 4     Adelie  Biscoe            60.7           17.9              177.0
# ...      ...     ...             ...            ...                ...
# 3425  Gentoo  Biscoe            44.0           20.4              252.0
# 3426  Gentoo  Biscoe            54.5           25.2              245.0
# 3427  Gentoo  Biscoe            51.4           20.4              258.0
# 3428  Gentoo  Biscoe            55.9           20.5              247.0
# 3429  Gentoo  Biscoe            43.9           22.9              206.0
#
#       body_mass_g     sex   diet life_stage health_metrics  year
# ...

# %%
penguinsExtended_df.describe()
# Out:
#        bill_length_mm  bill_depth_mm  flipper_length_mm   body_mass_g  \
# count     3430.000000    3430.000000        3430.000000   3430.000000
# mean        38.529825      18.447143         207.028863   4834.710496
# std         13.175171       2.774428          28.944765   1311.091310
# min         13.600000       9.100000         140.000000   2477.000000
# 25%         28.900000      16.600000         185.000000   3843.500000
# 50%         34.500000      18.400000         203.000000   4633.500000
# 75%         46.600000      20.300000         226.000000   5622.000000
# max         88.200000      27.900000         308.000000  10549.000000
#
#               year
# count  3430.000000
# mean   2023.348397
# std       1.313797
# min    2021.000000
# 25%    2022.000000
# 50%    2024.000000
# 75%    2024.000000
# max    2025.000000

# %%
penguinsExtended_df.columns
# Out:
# Index(['species', 'island', 'bill_length_mm', 'bill_depth_mm',
#        'flipper_length_mm', 'body_mass_g', 'sex', 'diet', 'life_stage',
#        'health_metrics', 'year'],
#       dtype='object')

# %% [markdown]
# ### • Existem valores ausentes ou inconsistentes no dataset? Se sim, como você trataria esses dados para garantir a qualidade da análise?
# #### R= Este DataSet exatamente não apresenta dados nulos ou faltantes, para verificar se apresentava dados nulos ou inconsistentes foi utilizada a função .isnull() junto a função .sum() para verificar a existencia mas retorno FALSO.

# %%
penguinsExtended_df.isnull()
# Out:
#       species  island  bill_length_mm  bill_depth_mm  flipper_length_mm  \
# 0       False   False           False          False              False
# 1       False   False           False          False              False
# 2       False   False           False          False              False
# 3       False   False           False          False              False
# 4       False   False           False          False              False
# ...       ...     ...             ...            ...                ...
# 3425    False   False           False          False              False
# 3426    False   False           False          False              False
# 3427    False   False           False          False              False
# 3428    False   False           False          False              False
# 3429    False   False           False          False              False
#
#       body_mass_g    sex   diet  life_stage  health_metrics   year
# ...

# %%
penguinsExtended_df.isnull().sum()
# Out:
# species              0
# island               0
# bill_length_mm       0
# bill_depth_mm        0
# flipper_length_mm    0
# body_mass_g          0
# sex                  0
# diet                 0
# life_stage           0
# health_metrics       0
# year                 0
# dtype: int64

# %%
# Analise Exploratoria de Dados
penguinsExtended_df[["bill_length_mm",
       "flipper_length_mm", "body_mass_g"]].describe()
# Out:
#        bill_length_mm  flipper_length_mm   body_mass_g
# count     3430.000000        3430.000000   3430.000000
# mean        38.529825         207.028863   4834.710496
# std         13.175171          28.944765   1311.091310
# min         13.600000         140.000000   2477.000000
# 25%         28.900000         185.000000   3843.500000
# 50%         34.500000         203.000000   4633.500000
# 75%         46.600000         226.000000   5622.000000
# max         88.200000         308.000000  10549.000000

# %% [markdown]
# ### • Crie gráficos para visualizar as diferenças entre as espécies de pinguins com base nas características físicas. Use gráficos de dispersão, boxplot e histogramas para mostrar as distribuições e comparações entre as variáveis.

# %%
plt.figure(figsize=(10, 6))
sn.scatterplot(data=penguinsExtended_df, x="bill_length_mm", y="bill_depth_mm", size="body_mass_g", hue="species", style="species")
plt.xlabel("Comprimento do bico")
plt.ylabel("Profundidade do bico")
plt.show()

# %%
penguinsExtended_df["species"].value_counts()

# %%
adelie_df = penguinsExtended_df[penguinsExtended_df["species"]=="Adelie"]
gento_df = penguinsExtended_df[penguinsExtended_df["species"]=="Gentoo"]
chinstrap_df = penguinsExtended_df[penguinsExtended_df["species"]=="Chinstrap"]

# %%
sn.set_style("whitegrid")
plt.boxplot([adelie_df["bill_length_mm"],gento_df["bill_length_mm"], chinstrap_df["bill_length_mm"]],labels=["Adelie","Gentoo","Chinstrap"])
plt.ylabel("Comprimento do bico")
plt.show()
sn.set_style("whitegrid")
plt.boxplot([adelie_df["bill_depth_mm"],gento_df["bill_depth_mm"], chinstrap_df["bill_depth_mm"]],labels=["Adelie","Gentoo","Chinstrap"])
plt.ylabel("Profundidade do bico")
plt.show()
sn.set_style("whitegrid")
plt.boxplot([adelie_df["body_mass_g"],gento_df["body_mass_g"], chinstrap_df["body_mass_g"]],labels=["Adelie","Gentoo","Chinstrap"])
plt.ylabel("Massa corporal")
plt.show()

# %%
plt.figure(figsize=(8, 5))
plt.title("Caracteristicas Penguins Adelie")
plt.hist([adelie_df["bill_length_mm"],adelie_df["bill_length_mm"]], bins=50, label=["Comprimento do bico","Profundidade do bico"])
plt.legend(loc="upper right")
plt.show()
plt.figure(figsize=(8,5))
plt.title("Massa Corporal Penguins Adelie")
plt.hist([adelie_df["body_mass_g"]], bins=50, label=["Massa Corporal"],color="green")
plt.legend(loc="upper right")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("Caracteristicas Penguins Gentoo")
plt.hist([gento_df["bill_length_mm"],gento_df["bill_length_mm"]], bins=50, label=["Comprimento do bico","Profundidade do bico"])
plt.legend(loc="upper right")
plt.show()
plt.figure(figsize=(8,5))
plt.title("Massa Corporal Penguins Gentoo")
plt.hist([gento_df["body_mass_g"]], bins=50, label=["Massa Corporal"],color="blue")
plt.legend(loc="upper right")
plt.show()

# %%
plt.figure(figsize=(8,5))
plt.title("Caracteristicas Penguins Chinstrap")
plt.hist([chinstrap_df["bill_length_mm"],chinstrap_df["bill_length_mm"]], bins=50, label=["Comprimento do bico","Profundidade do bico"])
plt.legend(loc="upper right")
plt.show()
plt.figure(figsize=(8,5))
plt.title("Massa Corporal Penguins Chinstrap")
plt.hist([chinstrap_df["body_mass_g"]], bins=50, label=["Massa Corporal"],color="blue")
plt.legend(loc="upper right")
plt.show()

# %% [markdown]
# ### Com base nas suas visualizações, escreva uma breve narrativa que conecte os dados com a situação atual dos pinguins. O que os dados sugerem sobre o habitat e as condições físicas desses animais? Como isso pode ser interpretado em relação às mudanças ambientais?
#
# #### R=Adelie, Gentoo e Chinstrap eram tres amigos inseparaveis, os tres gostavam da mesma comida, mas um dia estes tres amigos perceberam que cada vez era mais dificil consguir alimento, pois seu ambiente estava mudando. Adelie que era uma aventurera nata, fazia o possivel para se adaptar ao cambio nadando o mais longe possivel, Gentoo que era o mais sabio, buscou novas formas de alimento, alguns dos seus compatriotas tiveram que ir mais longe para se adaptar melhor, e Chinstrap que observa tudo, ficava atento e registrava cada mudança. A pesar dos cambios e as dificuldade, a sua amizade era muito forte e aprenderam a sobreviver em um mundo que esta em constante cambio e transformação
