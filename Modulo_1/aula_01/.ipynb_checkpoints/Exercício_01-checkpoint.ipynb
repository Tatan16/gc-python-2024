# %% [markdown]
# # Exercicio 1

# %% [markdown]
# ## Crie um programa que leia seu nome e imprima na tela.

# %%
## Pedindo nome e mostrando mensagem na tela
nome = input("Digite seu nome: ")
print(f"Seu nome é: {nome}")
# Out:
# Digite seu nome:  Jhonathan
# Seu nome é: Jhonathan
